# %% [markdown]
# <a href="https://colab.research.google.com/github/antoinehicks23/Infrastructure-intelligence-lab/blob/main/algo_trading_system_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import subprocess
result = subprocess.run(['git', 'clone', 'https://github.com/antoinehicks23/Infrastructure-intelligence-lab.git'], capture_output=True, text=True)
print(result.stdout)
print(result.stderr)
# Out:
# Cloning into 'Infrastructure-intelligence-lab'...

# %%
import os
os.listdir('/content')
# Out:
# ['.config', 'Infrastructure-intelligence-lab', 'drive', 'sample_data']

# %%
import sys
import os
print(os.listdir('/content/Infrastructure-intelligence-lab'))
# Out:
# ['README.md', 'Maintenance_Intelligence', 'Mosh_python_journey', 'financial_models', '.git', 'Vp_orb_v2.py', '.gitignore']

# %%
import sys
sys.argv = ['Vp_orb_v2.py']
exec(open('/content/Infrastructure-intelligence-lab/Vp_orb_v2.py').read())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13974/3000103509.py in <cell line: 0>()
#       1 import sys
#       2 sys.argv = ['Vp_orb_v2.py']
# ----> 3 exec(open('/content/Infrastructure-intelligence-lab/Vp_orb_v2.py').read())
#
# <string> in <module>
#
# NameError: name 'true' is not defined
